# %%
#JUVENILE TOP 5
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir("C:/Users/DELL/Desktop/DAP dataset")

juvenile_crime_data = pd.read_csv("juvenile_crime.csv")

# Extract necessary columns for plotting
states = juvenile_crime_data["STATE NAME"]
years = ['JUVENILE CRIME (2014)', 'JUVENILE CRIME (2015)', 'JUVENILE CRIME (2016)']

# Calculate total juvenile crimes for each state
juvenile_crime_data['Total Juvenile Crimes'] = juvenile_crime_data[years].sum(axis=1)

# Get the top 5 states with the highest total juvenile crimes
top_states = juvenile_crime_data.nlargest(5, 'Total Juvenile Crimes')['STATE NAME']

# Plotting for the top 5 states
plt.figure(figsize=(12, 8))

for state in top_states:
    state_data = juvenile_crime_data[juvenile_crime_data["STATE NAME"] == state]
    plt.plot(years, state_data[years].values.flatten(), label=state)

plt.title('Juvenile Crime Over 3 Years (2014-2016) - Top 5 States')
plt.xlabel('Year')
plt.ylabel('Number of Juvenile Crimes')
plt.legend()
plt.show()

# %%
#top 5 Child crime
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir("C:/Users/DELL/Desktop/DAP dataset")
child_crime_data = pd.read_csv("crime_against_children.csv")

# Extract necessary columns for plotting
states = child_crime_data["STATE NAME"]
years = ['CHILDREN CRIME (2014)', 'CHILDREN CRIME (2015)', 'CHILDREN CRIME (2016)']

# Calculate total juvenile crimes for each state
child_crime_data['Total Child Crimes'] = child_crime_data[years].sum(axis=1)

# Get the top 5 states with the highest total juvenile crimes
top_states = child_crime_data.nlargest(5, 'Total Child Crimes')['STATE NAME']

# Plotting for the top 5 states
plt.figure(figsize=(12, 8))

for state in top_states:
    state_data = child_crime_data[child_crime_data["STATE NAME"] == state]
    plt.plot(years, state_data[years].values.flatten(), label=state)

plt.title('Child Crime Over 3 Years (2014-2016) - Top 5 States')
plt.xlabel('Year')
plt.ylabel('Number of child Crimes')
plt.legend()
plt.show()

# %%
#Cyber top 5
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir("C:/Users/DELL/Desktop/DAP dataset")

cyber_crime_data = pd.read_csv("cyber_crime.csv")

# Extract necessary columns for plotting
states = cyber_crime_data["STATE NAME"]
years = ['CYBER CRIME (2014)', 'CYBER CRIME (2015)', 'CYBER CRIME (2016)']

# Calculate total juvenile crimes for each state
cyber_crime_data['Total Cyber Crimes'] = cyber_crime_data[years].sum(axis=1)

# Get the top 5 states with the highest total juvenile crimes
top_states = cyber_crime_data.nlargest(5, 'Total Cyber Crimes')['STATE NAME']

# Plotting for the top 5 states
plt.figure(figsize=(12, 8))

for state in top_states:
    state_data = cyber_crime_data[cyber_crime_data["STATE NAME"] == state]
    plt.plot(years, state_data[years].values.flatten(), label=state)

plt.title('Cyber Crime Over 3 Years (2014-2016) - Top 5 States')
plt.xlabel('Year')
plt.ylabel('Number of Cyber Crimes')
plt.legend()
plt.show()

# %%
#corruption top 5
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir("C:/Users/DELL/Desktop/DAP dataset")

corruption_crime_data = pd.read_csv("coruption_case.csv")

# Extract necessary columns for plotting
states = child_crime_data["STATE NAME"]
years = ['CORRUPTION CASE (2014)', 'CORRUPTION CASE (2015)', 'CORRUPTION CASE (2016)']

# Calculate total juvenile crimes for each state
corruption_crime_data['Total CORRUPTION Crimes'] = corruption_crime_data[years].sum(axis=1)

# Get the top 5 states with the highest total juvenile crimes
top_states = corruption_crime_data.nlargest(5, 'Total CORRUPTION Crimes')['STATE NAME']

# Plotting for the top 5 states
plt.figure(figsize=(12, 8))

for state in top_states:
    state_data = corruption_crime_data[corruption_crime_data["STATE NAME"] == state]
    plt.plot(years, state_data[years].values.flatten(), label=state)

plt.title('CORRUPTION Crime Over 3 Years (2014-2016) - Top 5 States')
plt.xlabel('Year')
plt.ylabel('Number of CORRUPTION Crimes')
plt.legend()
plt.show()

# %%
#CRIME overall top 5
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir("C:/Users/DELL/Desktop/DAP dataset")

crime_data = pd.read_csv("crimes.csv")

# Extract necessary columns for plotting
states = child_crime_data["STATE NAME"]
years = ['CRIME (2014)', 'CRIME (2015)', 'CRIME (2016)']

# Calculate total juvenile crimes for each state
corruption_crime_data['Total Crimes'] = crime_data[years].sum(axis=1)

# Get the top 5 states with the highest total juvenile crimes
top_states = corruption_crime_data.nlargest(5, 'Total Crimes')['STATE NAME']

# Plotting for the top 5 states
plt.figure(figsize=(12, 8))

for state in top_states:
    state_data = crime_data[crime_data["STATE NAME"] == state]
    plt.plot(years, state_data[years].values.flatten(), label=state)

plt.title('Crime Over 3 Years (2014-2016) - Top 5 States')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.legend()
plt.show()

# %%
#Juvenile Education Distribution in Uttar Pradesh
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir("C:/Users/DELL/Desktop/dap mine")
df = pd.read_excel("juvi_education.xlsx")

# Filter data for Uttar Pradesh
up_data = df[df['Area_Name'] == 'Uttar Pradesh']

# Sum the values across all years
up_total = up_data.groupby('Sub_Group_Name').sum()

# Select the relevant columns for the pie chart
education_columns = ['Education_Above_Primary_but_below_Matric_or_Higher_Secondary',
                     'Education_Illiterate',
                     'Education_Matric_or_Higher_Secondary_&_above',
                     'Education_Upto_primary']

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(up_total[education_columns].iloc[0], labels=education_columns, autopct='%1.1f%%', startangle=140)
plt.title('Juvenile Education Distribution in Uttar Pradesh (2001-2016)')
plt.show()

# %%
#Juvenile Background Distribution in Uttar Pradesh
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir("C:/Users/DELL/Desktop/dap mine")
df = pd.read_excel("juvi_background.xlsx")

# Filter data for Uttar Pradesh
up_data = df[df['Area_Name'] == 'Uttar Pradesh']

# Sum the values across all years
up_total = up_data.groupby('Sub_Group_Name').sum()

# Select the relevant columns for the pie chart
education_columns = ['Family_back_ground_Homeless','Family_back_ground_Living_with_guardian','Family_back_ground_Living_with_parents']


# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(up_total[education_columns].iloc[0], labels=education_columns, autopct='%1.1f%%', startangle=140)
plt.title('Juvenile Background Distribution in Uttar Pradesh (2001-2016)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

os.chdir("C:/Users/DELL/Desktop/dap mine")

df = pd.read_excel("juvi_economics.xlsx")

# Filter data for Uttar Pradesh
up_data = df[df['Area_Name'] == 'Uttar Pradesh']

# Sum the values across all years
up_total = up_data.groupby('Sub_Group_Name').sum()

# Select the relevant columns for the bar chart
economic_columns = ['25000 to 50000',
                     'upto Rs 25000',
                     '100000 to 200000',
                     '50000 to 100000',
                     'Above Rs 300000',
                     '200000 to 300000']

# Plot the bar chart with custom legends
plt.figure(figsize=(10, 6))
ax = up_total[economic_columns].iloc[0].plot(kind='bar', color='purple')

# Customize legends
legend_labels = ['25,000 to 50,000', 'Up to 25,000', '10,000 to 2,00,000', '50,000 to 1,00,000', 'Above 3,00,000']
ax.legend(legend_labels, title='Annual Income Range')

plt.xlabel('Economic Background')
plt.ylabel('Number of Cases')
plt.title('Juvenile Economic Background Distribution in Uttar Pradesh (2001-2016)')
plt.show()
